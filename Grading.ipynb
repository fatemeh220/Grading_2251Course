# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemeh220/Grading_2251Course/blob/main/Grading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

Student_OWL = pd.read_csv("list_student_OWL.csv")
Student_OWL = Student_OWL.iloc[:,:3]
Student_OWL.head()
# Out:
#   Student ID              Name  # Student Number
# 0      kagne    Agne, Khennery         251221504
# 1   malhanaf  Al-Hanafi, Malak         251142157
# 2    marif27      Arif, Mariam         251239114
# 3    obhatt3         Bhatt, Om         251256665
# 4   jcamill5   Camillo, Joshua         251199106

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Deadline = '2023-01-20'
Assignment_Repo_URL_End = '/blob/main/hello.py'
Student_Github=pd.read_csv("Github_Score_PrepareAndTest.csv")
Assignment_Name =Student_Github['assignment_name'][0]
Student_Github.head()

Student_Github = Student_Github[['roster_identifier','submission_timestamp','points_awarded','student_repository_url']]
Student_Github.columns = ['Student ID', 'Time','Grade','Link']
Student_Github.head()

Student_OWL = Student_OWL.merge(Student_Github, how='left')
Student_OWL.head()
# Out:
#   Student ID              Name  # Student Number                     Time  \
# 0      kagne    Agne, Khennery         251221504  2023-01-17 22:45:49 UTC
# 1   malhanaf  Al-Hanafi, Malak         251142157  2023-01-20 06:10:03 UTC
# 2    marif27      Arif, Mariam         251239114  2023-01-18 20:30:34 UTC
# 3    obhatt3         Bhatt, Om         251256665  2023-01-21 00:20:33 UTC
# 4   jcamill5   Camillo, Joshua         251199106  2023-01-17 00:13:43 UTC
#
#    Grade                                               Link
# 0    0.0  https://github.com/ShaimaaAliECE/prepareandtes...
# 1   10.0  https://github.com/ShaimaaAliECE/prepareandtes...
# 2    0.0  https://github.com/ShaimaaAliECE/prepareandtes...
# 3   10.0  https://github.com/ShaimaaAliECE/prepareandtes...
# 4   10.0  https://github.com/ShaimaaAliECE/prepareandtes...

# %%
Student_OWL
# Out:
#    Student ID                     Name  # Student Number  \
# 0       kagne           Agne, Khennery         251221504
# 1    malhanaf         Al-Hanafi, Malak         251142157
# 2     marif27             Arif, Mariam         251239114
# 3     obhatt3                Bhatt, Om         251256665
# 4    jcamill5          Camillo, Joshua         251199106
# 5        eco2               Co, Edmund         251219772
# 6     ecook46             Cook, Elijah         251219963
# 7     cdenomy           Denomy, Clarke         251228986
# 8       sdiep             Diep, Shayla         251241588
# 9      ldoan8       Doan, Le Hoang Anh         251216495
# 10      neng3              Eng, Nathan         251219031
# 11   sghebrek      Ghebrekidan, Semere         251217150
# 12   cgilbe27          Gilbert, Connor         251239309
# 13    jgivans           Givans, Joshua         251248613
# 14   agoyal57             Goyal, Arnav         251244778
# 15     bguo48             Guo, Bingxin         251217980
# 16   mhebbert         Hebbert, Matthew         251244953
# 17   jhong324              Hong, Jaden         251228650
# 18   tjones89             Jones, Trent         251228052
# 19     lkalab             Kalab, Laura         251220769
# 20    jkaniuk             Kaniuk, John         251250946
# 21    jkeane7             Keane, James         251239268
# 22    nkirchb        Kirchberger, Neil         251210108
# 23    hkorble           Korble, Hunter         251200643
# 24   clatosi2  Latosinsky, Christopher         251240736
# 25    lmayer5              Mayer, Luke         251221581
# 26   jminevic         Minevich, Jasmin         251232401
# 27    amitc32          Mitchell, Aidan         251222232
# 28   mmunir22          Munir, Muhammad         251215948
# 41  2023-01-18 19:03:58 UTC   10.0
# 42  2023-01-20 19:24:07 UTC   10.0
# 43  2023-01-15 01:31:25 UTC   10.0
# 44  2023-01-18 20:53:07 UTC   10.0
# 45  2023-01-17 15:17:19 UTC   10.0
# 46  2023-01-16 19:47:43 UTC   10.0
# 47  2023-01-18 15:05:43 UTC    0.0
# 48  2023-01-18 21:36:05 UTC   10.0
# 49  2023-01-17 16:34:07 UTC   10.0
# 50  2023-01-16 00:47:16 UTC   10.0
# 51  2023-01-17 00:31:57 UTC   10.0
# 52  2023-01-17 01:29:56 UTC   10.0
#
#                                                  Link
# 0   https://github.com/ShaimaaAliECE/prepareandtes...
# 1   https://github.com/ShaimaaAliECE/prepareandtes...
# 2   https://github.com/ShaimaaAliECE/prepareandtes...
# 3   https://github.com/ShaimaaAliECE/prepareandtes...
# 4   https://github.com/ShaimaaAliECE/prepareandtes...
# 5   https://github.com/ShaimaaAliECE/prepareandtes...
# 6   https://github.com/ShaimaaAliECE/prepareandtes...
# 7   https://github.com/ShaimaaAliECE/prepareandtes...
# 8   https://github.com/ShaimaaAliECE/prepareandtes...
# 9   https://github.com/ShaimaaAliECE/prepareandtes...
# 10  https://github.com/ShaimaaAliECE/prepareandtes...
# 11                                                NaN
# 12  https://github.com/ShaimaaAliECE/prepareandtes...
# 13  https://github.com/ShaimaaAliECE/prepareandtes...
# 14  https://github.com/ShaimaaAliECE/prepareandtes...
# 15  https://github.com/ShaimaaAliECE/prepareandtes...
# 16  https://github.com/ShaimaaAliECE/prepareandtes...
# 17  https://github.com/ShaimaaAliECE/prepareandtes...
# 18  https://github.com/ShaimaaAliECE/prepareandtes...
# 19  https://github.com/ShaimaaAliECE/prepareandtes...
# 20  https://github.com/ShaimaaAliECE/prepareandtes...
# 21  https://github.com/ShaimaaAliECE/prepareandtes...
# 22  https://github.com/ShaimaaAliECE/prepareandtes...
# 23  https://github.com/ShaimaaAliECE/prepareandtes...
# 24  https://github.com/ShaimaaAliECE/prepareandtes...
# 25  https://github.com/ShaimaaAliECE/prepareandtes...
# 26  https://github.com/ShaimaaAliECE/prepareandtes...
# 27  https://github.com/ShaimaaAliECE/prepareandtes...
# 28  https://github.com/ShaimaaAliECE/prepareandtes...
# 29  https://github.com/ShaimaaAliECE/prepareandtes...
# 30  https://github.com/ShaimaaAliECE/prepareandtes...
# 31  https://github.com/ShaimaaAliECE/prepareandtes...
# 32  https://github.com/ShaimaaAliECE/prepareandtes...
# 33  https://github.com/ShaimaaAliECE/prepareandtes...
# 34  https://github.com/ShaimaaAliECE/prepareandtes...
# 35  https://github.com/ShaimaaAliECE/prepareandtes...
# 36  https://github.com/ShaimaaAliECE/prepareandtes...
# 37  https://github.com/ShaimaaAliECE/prepareandtes...
# 38  https://github.com/ShaimaaAliECE/prepareandtes...
# 39  https://github.com/ShaimaaAliECE/prepareandtes...
# 40  https://github.com/ShaimaaAliECE/prepareandtes...
# 41  https://github.com/ShaimaaAliECE/prepareandtes...
# 42  https://github.com/ShaimaaAliECE/prepareandtes...
# 43  https://github.com/ShaimaaAliECE/prepareandtes...
# 44  https://github.com/ShaimaaAliECE/prepareandtes...
# 45  https://github.com/ShaimaaAliECE/prepareandtes...
# 46  https://github.com/ShaimaaAliECE/prepareandtes...
# 47  https://github.com/ShaimaaAliECE/prepareandtes...
# 48  https://github.com/ShaimaaAliECE/prepareandtes...
# 49  https://github.com/ShaimaaAliECE/prepareandtes...
# 50  https://github.com/ShaimaaAliECE/prepareandtes...
# 51  https://github.com/ShaimaaAliECE/prepareandtes...
# 52  https://github.com/ShaimaaAliECE/prepareandtes...

# %%
for i in Student_OWL.index:
  if Student_OWL['Grade'][i]==0:
    print('The link is: '+ str(Student_OWL['Link'][i])+ Assignment_Repo_URL_End)
    Student_OWL['Grade'][i] = input('Please enter the updated grade for %s: ' %(Student_OWL['Student ID'][i]))
# Out:
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-KhenneryAgne/blob/main/hello.py
# Please enter the updated grade for kagne: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-marif5520/blob/main/hello.py
# Please enter the updated grade for marif27: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-MHebbert/blob/main/hello.py
# Please enter the updated grade for mhebbert: 0
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-t-jones89/blob/main/hello.py
# Please enter the updated grade for tjones89: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-JohnKaniukSchool/blob/main/hello.py
# Please enter the updated grade for jkaniuk: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-lmayer5/blob/main/hello.py
# Please enter the updated grade for lmayer5: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-amitc32/blob/main/hello.py
# Please enter the updated grade for amitc32: 0
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-MuhammadMunir123/blob/main/hello.py
# Please enter the updated grade for mmunir22: 10
# The link is: https://github.com/ShaimaaAliECE/prepareandtest-ThunderFlame2230/blob/main/hello.py
# Please enter the updated grade for atriguer: 0

# %%
from datetime import datetime
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

Student_OWL['Delay'] = 0
Student_OWL['Grade_initial'] = Student_OWL['Grade']

for i in range(Student_OWL.shape[0]):
  # if(math.isnan(pd.to_numeric(Student_OWL['Time'][i]))):
  #   i=i+1
  try:
    res = datetime.strptime(Deadline, '%Y-%m-%d') - datetime.strptime(Student_OWL['Time'][i][:10], '%Y-%m-%d')
    number_of_days = res.days
    # res = datetime.strptime(datetime.strptime('2023-01-20', '%Y-%m-%d') - datetime.strptime(Student_OWL['Time'][i][:10], '%Y-%m-%d'))
    # number_of_days = res.days
    if(number_of_days<0):
      Student_OWL.Grade[i]=Student_OWL.Grade[i]*(1+(number_of_days)*0.1)
      Student_OWL['Delay'][i] = -number_of_days

  except:
  #   # i=i+1
    Student_OWL.Grade[i] = 0
 
Student_OWL.head()
# Out:
#   Student ID              Name  # Student Number                     Time  \
# 0      kagne    Agne, Khennery         251221504  2023-01-17 22:45:49 UTC
# 1   malhanaf  Al-Hanafi, Malak         251142157  2023-01-20 06:10:03 UTC
# 2    marif27      Arif, Mariam         251239114  2023-01-18 20:30:34 UTC
# 3    obhatt3         Bhatt, Om         251256665  2023-01-21 00:20:33 UTC
# 4   jcamill5   Camillo, Joshua         251199106  2023-01-17 00:13:43 UTC
#
#    Grade                                               Link  Delay  \
# 0   10.0  https://github.com/ShaimaaAliECE/prepareandtes...      0
# 1   10.0  https://github.com/ShaimaaAliECE/prepareandtes...      0
# 2   10.0  https://github.com/ShaimaaAliECE/prepareandtes...      0
# 3    9.0  https://github.com/ShaimaaAliECE/prepareandtes...      1
# 4   10.0  https://github.com/ShaimaaAliECE/prepareandtes...      0
#
#    Grade_initial
# 0           10.0
# 1           10.0
# 2           10.0
# 3           10.0
# 4           10.0

# %%
Student_OWL
# Out:
#    Student ID                     Name  # Student Number  \
# 0       kagne           Agne, Khennery         251221504
# 1    malhanaf         Al-Hanafi, Malak         251142157
# 2     marif27             Arif, Mariam         251239114
# 3     obhatt3                Bhatt, Om         251256665
# 4    jcamill5          Camillo, Joshua         251199106
# 5        eco2               Co, Edmund         251219772
# 6     ecook46             Cook, Elijah         251219963
# 7     cdenomy           Denomy, Clarke         251228986
# 8       sdiep             Diep, Shayla         251241588
# 9      ldoan8       Doan, Le Hoang Anh         251216495
# 10      neng3              Eng, Nathan         251219031
# 11   sghebrek      Ghebrekidan, Semere         251217150
# 12   cgilbe27          Gilbert, Connor         251239309
# 13    jgivans           Givans, Joshua         251248613
# 14   agoyal57             Goyal, Arnav         251244778
# 15     bguo48             Guo, Bingxin         251217980
# 16   mhebbert         Hebbert, Matthew         251244953
# 17   jhong324              Hong, Jaden         251228650
# 18   tjones89             Jones, Trent         251228052
# 19     lkalab             Kalab, Laura         251220769
# 20    jkaniuk             Kaniuk, John         251250946
# 21    jkeane7             Keane, James         251239268
# 22    nkirchb        Kirchberger, Neil         251210108
# 23    hkorble           Korble, Hunter         251200643
# 24   clatosi2  Latosinsky, Christopher         251240736
# 25    lmayer5              Mayer, Luke         251221581
# 26   jminevic         Minevich, Jasmin         251232401
# 27    amitc32          Mitchell, Aidan         251222232
# 28   mmunir22          Munir, Muhammad         251215948
# 29   dndabiha       Ndabihayimana, Dan         251217466
# 30     lndoja             Ndoja, Luigj         251207961
# 31    nnguy25           Nguyen, Nathan         251202197
# 32       anuh               Nuh, Aysha         251209455
# 33   apanesa8          Panesar, Arveen         251224963
# 34   epark225               Park, Evan         251215296
# 35   dpate487               Patel, Dev         251216138
# 36   spate738              Patel, Shiv         251230295
# 37   dperezde   Perez De Camino, Diego         251203341
# 38   fprentic       Prentice, Benjamin         251219634
# 39   aribeir4       Ribeiro, Alexandre         251244760
# 40    asarauz          Sarauz, Anthony         251217780
# 41    esharm2            Sharma, Eesha         251219034
# 42   asohrab6         Sohrabian, Aaron         251229522
# 43    mstrasm       Strasman, Mitchell         251215077
# 44   msuthe43      Sutherland, Matthew         251198984
# 45   msylves6       Sylvester, Madison         251219111
# 46   jszyman3         Szymanski, James         251237012
# 47   atriguer          Triguero, Aaron         251193637
# 48   ovanvoor         Van Voorst, Owen         251237618
# 49    gwatt23             Watt, Graeme         251201502
# 50    dwaugh5            Waugh, Duncan         251246391
# 51    dwepple          Weppler, Daniel         251226405
# 52   jwill345              Will, Jaxon         251238122
#
#                        Time  Grade  \
# 0   2023-01-17 22:45:49 UTC   10.0
# 8   https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 9   https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 10  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 11                                                NaN      0            NaN
# 12  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 13  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 14  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 15  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 16  https://github.com/ShaimaaAliECE/prepareandtes...      0            0.0
# 17  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 18  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 19  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 20  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 21  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 22  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 23  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 24  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 25  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 26  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 27  https://github.com/ShaimaaAliECE/prepareandtes...      0            0.0
# 28  https://github.com/ShaimaaAliECE/prepareandtes...      1           10.0
# 29  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 30  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 31  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 32  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 33  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 34  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 35  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 36  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 37  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 38  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 39  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 40  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 41  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 42  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 43  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 44  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 45  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 46  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 47  https://github.com/ShaimaaAliECE/prepareandtes...      0            0.0
# 48  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 49  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 50  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 51  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0
# 52  https://github.com/ShaimaaAliECE/prepareandtes...      0           10.0

# %%
Student_OWL.to_csv(Assignment_Name+'.csv', index=False)
